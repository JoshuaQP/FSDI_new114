# %%
print("hello, world!")
# Out:
# hello, world!

# %%
for letter in "hello, world!":
    print(letter)
# Out:
# h
# e
# l
# l
# o
# ,
#
# w
# o
# r
# l
# d
# !

# %% [markdown]
# # Problem
# ### Given two strings (strings_a and string_b) lets check weather or not they areanagrams of each other the following critetria:
# two string are only anagrams of each other if all condition below are met:
# they must be exactly the same length.
# they must use exactly the same charchter(no more, no less). Example: cars and scar, heart and earth.

# %%
def is_anagram(string_a, string_b):
    if len(string_a) != len(string_b):
        return False
    char_times_a = dict()
    char_times_b = dict()
    for i in range(len(string_a)):
        if string_a[i] not in char_times_a.keys():
            char_times_a[string_a[i]] = 0
        else:
            char_times_a[string_a[i]] += 1
        if string_b[i] not in char_times_b.keys():
            char_times_b[string_b[i]] = 0
        else:
            char_times_b[string_b[i]] += 1
    return char_times_a == char_times_b

# %%
is_anagram("cars", "scar")
# Out:
# True

# %%
is_anagram("sccr", "scar")
# Out:
# False

# %%
is_anagram("I am lord voldemort", "Tom Marvolo Riddle")
# Out:
# False

# %%
class Stack:
    def __init__(self):
        self.items = []
        
    def is_empty(self):
        return self.items == []
        
    def push(self, item):
        self.items.append(item)
            
    def pop(self):
        return self.items.pop()
    
    def peek(self):
        return self.items[len(self.items)-1]
    
    def size(self):
        return len(self.items)

# %%
def reverse_str(s):
    out = ""
    stack = Stack()
    for letter in s:
        stack.push(letter)
    while not stack.is_empty():
        out += stack.pop()
    return out

# %%
reverse_str("josh")
# Out:
# auhsoj

# %%
x = "Josh"
y = (x.replace(" ", " ")).lower()
print(y)
# Out:
# josh

# %%
# Problem 3 
### Using out stack class implement a back button so that the stack returns the last visted Wrl When the user requests it.
## first, well load 10 urls into stack(to mock the data) then we

# %%
urls = [
    "www.google.com",
    "twitter.com",
    "facebook.com",
    "duckduckgo.com",
    "sdgku.edu",
    "something.com",
    "example.com",
    "mywebpage.com",
    "gmail.com",
    "hotmail.com"
]

# %%
x = input("what?")
print("hello %s!" % x)
# Out:
# what?josh
# hello josh!

# %%
y = input (  "  Do you want the last url?" )
print(y)
# Out:
#  josh! Do you want the last url?yes
# yes

# %%
def back_button(list_urls):
    stack = Stack()
    user_input ="yes"
    for url in list_urls:
        stack.push(url)
    while user_input != "no" and not stack.is_empty():
        user_input = input("Do you want the last url?")
        if user_input == "yes":
            print("last url: %s" % stack.pop())
        if stack.is_empty():
            print("No more elements in stack!")

# %%
back_button(urls)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_795/3881755075.py in <module>
# ----> 1 back_button(urls)
#
# /tmp/ipykernel_795/1590124184.py in back_button(list_urls)
#       1 def back_button(list_urls):
# ----> 2     stack = Stack()
#       3     for url in list_urls:
#       4         stack.push(url)
#       5     y = input("Do you want the last url?")
#
# /tmp/ipykernel_795/4257171191.py in __init__(self)
#       1 class Stack:
#       2     def __init__(self):
# ----> 3         self.items == []
#       4
#       5     def push(self, item):
#
# AttributeError: 'Stack' object has no attribute 'items'
