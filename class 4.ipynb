# %%
class Node:
    
    def __init__(self, data):
        self.data = data
        self.next = None
        
        
class LinkedList:
    
    def __init__(self):
        self.head = None
        self.tail = None
    
    
    def serach(self, target):          #our target param represesnts the data we're looking for
        current = self.head            # we initialiuze "current at the head of out list"
        found = False                  # create a boolean variable "found " that represnt the search state
        while current:                # loop as long as current is not None (see Nonetype)
            if current.data == target: # if the node referance by "Current" has the data we're looking for
                found = True           # .. set found to True and..
                break                  # exit loop
            current = current.next     #current will poin to the next noede in our list
        return found
    
    
    def index(self, target):
        current = self.head
        index = -1 
        while current:
            if current.data = True:
     
    
        
    def data_at(self, index):
        current = self.head
        current_index = 0
        
        while current:
            if index == current_index:
                return current.data
            current = current.next
            current_index += 1
            
        raise Exception("index out of bounds")
        
        
        def prepend(self, data)
            node = Node(data)
            # stor a temporary reference to our current "head":
            current_head = self.load
            #set self.head so that it points to "node":
            self.head = node
            # link our "node" at self.head to "current_head" thus linking to the rest of out list:
            self.head.next = current_head
            
            
#         def append(self, data):
#             if not self.head:
#                 self.head = Node(data)
#             else:
#             # linkes 1-3: loop until we find the end of our list.
#                current = self.head
#                 while current.next:
#                     current = current.next     
#                 current.next = Node(data)
        
        
            
    
        def get_tail(self):
            if self.tail:
                return self.tail
            if not self.head:
                return None
            current = self.head
            while current.next:
                current = current.next
            self.tail = current
            return self.tail
        
        def append(self,data):
            current = self.get_tail()
            if not current:
                self.head = Node(data)
                self.tail = self.head
            else:
                current.next = Node(data)
                self.tail = current.next
                
        def insert(self, index_after, data):
            tail =self.get_tail()
            if not tail:
                raise Exception ("Refrence to head not set.")
            current = self.head
            current_index = 0
            found = False
            while current:
                if current_index == index_after:
                    new_node = Node(data)
                    current.next = Node(data)
                    if cnew_node.next == None:
                        self.tail = new_code
                        found = True
                    break
                current = cureent.next
                current_index += 1
            if not Found:
                raise Exception(" Index out of bounds.")
                
        def remove(self, target):
            tail = self.get_tail()
            if not self.head:
                raise Exception("Reference to head not set.")
            current = self.head
            found = False
            if current.data == target:
                self.head = self.head.next
            while current.next:
                previous = current
                current = current.next
                if current.data == target:
                    previous.next = current.next
                    found = True
                    if previous.next == None:
                        self.tail = previous     
            if not found:
                raise Exception("Target not in list.")
                
                
        def __str__(self):
            current = self.head
            out = ""
            while current:
                print("%d, " % current.data)
                current = current.next
            print("[%s]" % out)
# Out:
#   File "/tmp/ipykernel_827/1342784766.py", line 30
#     if current.data = True:
#                     ^
# SyntaxError: invalid syntax

# %%
my_list = LinkedList()

for number in range(10):
    my_list.append(number)
    
print(my_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_827/3217126139.py in <module>
#       2
#       3 for number in range(10):
# ----> 4     my_list.append(number)
#       5
#       6 print(my_list)
#
# AttributeError: 'LinkedList' object has no attribute 'append'

# %%
a = [1, 2, 3, 4, ]
print()

# %%
class DNode:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None
        
class DLList:
    def __init__(self, data):
        self.head = None
        
    def get_tail(self)
    
    
    def append(self,data):
        if not self.head:
            new_node =DNode(data)
            self.head = new_node
        else:
            current = self.head:
            while current:
                current = current.next
            new_node = Dnode(data)
            current.next = new_code
            new_node.prev = current
    
    
        
         
        
        
        
        
        
        
    def remove_last(self,data):
        tail = self.tail()
        current = self.head
        if not self.head:
            return False
            
        if current.data == data:
            self.head = self.head.next
            self.head.prev = None
            return True
        while current.next:
            previous = current
            current = current.next
        if current.data == data:
            previous.next = current.next
            found = True
        if previous.next == None:
            self.tail = previous
        if not found:
            return current data

# %%
# Out:
#   File "/tmp/ipykernel_827/3665461298.py", line 5
#     if current.data == data:
#     ^
# IndentationError: expected an indented block
